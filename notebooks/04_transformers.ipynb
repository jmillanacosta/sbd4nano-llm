# %% [markdown]
# https://docs.google.com/spreadsheets/d/1CFGZq90xc1V0ARubq3ZXT5G2KoMewEJWazLnCtIIa5M/edit#gid=0
#
# https://huggingface.co/datasets/squad
#
# https://github.com/huggingface/transformers/tree/main/examples/pytorch/question-answering
#
# Create question answering training dataset from GO table:
# - answer_start = integer marking the start position of the annotated answer in the full text file
# - text = text of the answer
# - context = full text
# - id = number from (0, len(GO))
# - question: Does the Graphene Oxide {property} correlate positively or negatively with {effect} in {biosystem_organism}?
# - title = title for question

# %%
import os
import pandas as pd
import re
from unstructured.partition.auto import partition

# %%
go = pd.read_csv('../data/go.tsv', sep="\t") #.dropna(how='any')
dois = [str(article) for article in set(go['doi']) if 'doi' in str(article)]
#go = go[go['doi'].isin(dois)]
#go['filenames'] = ['../data/docs/'+i.replace('http://', '').replace('doi.org/', '').replace('/', '.').replace('dx.', '') for i in go['doi']]
go.columns
# Out:
# Index(['property', 'effect', 'type_relation', 'dose', 'material',
#        'biosystem_organism', 'dose.1', 'coating', 'diameter_type', 'diameter',
#        'Material properties', 'quote', 'doi'],
#       dtype='object')

# %%
go.describe(include='all')
# Out:
#         property    effect         type_relation        dose material  \
# count         61        61                    51          14       95
# unique        16        23                     4          11        8
# top     exposure  toxicity  PositivelyCorrelates  < 20 μg/mL       GO
# freq          17        15                    21           2       68
# mean         NaN       NaN                   NaN         NaN      NaN
# std          NaN       NaN                   NaN         NaN      NaN
# min          NaN       NaN                   NaN         NaN      NaN
# 25%          NaN       NaN                   NaN         NaN      NaN
# 50%          NaN       NaN                   NaN         NaN      NaN
# 75%          NaN       NaN                   NaN         NaN      NaN
# max          NaN       NaN                   NaN         NaN      NaN
#
#                                        biosystem_organism              dose.1  \
# count                                                  58                   9
# unique                                                 35                   5
# top     Daphnia magnadoses (1–50 mg.L) and exposure ti...  2 μg/mL to 6 μg/mL
# freq                                                    6                   4
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#         coating          diameter_type        diameter  \
# count       0.0                      1               3
# unique      NaN                      1               1
# top         NaN  hydrodynamic diameter  100nm to 110nm
# freq        NaN                      1               3
# mean        NaN                    NaN             NaN
# std         NaN                    NaN             NaN
# min         NaN                    NaN             NaN
# 25%         NaN                    NaN             NaN
# 50%         NaN                    NaN             NaN
# 75%         NaN                    NaN             NaN
# max         NaN                    NaN             NaN
#
#                                       Material properties  \
# count                                                  45
# unique                                                 16
# top     GO layers with a median size of 200–300 nm. av...
# freq                                                    8
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                     quote  \
# count                                                 105
# unique                                                 82
# top     This review reveals that the toxicity of graph...
# freq                                                    6
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  doi
# count                             99
# unique                            17
# top     dx.doi.org/10.1021/tx400385x
# freq                              47
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN

# %%
def strip_xml_tags(text):
    # Remove XML tags from the text using regular expressions
    return re.sub(r'<[^>]+>', '', text)

def get_full_text(doi):
    my_files = os.listdir('../data/docs')
    doi = doi.split("/")[-1]
    if '/' in doi:
        doi = doi.split('/')[1]
    
    for file in my_files:
        if doi in file:
            filepath = os.path.join('../data/docs', file)
            print(f'Parsing {filepath}')
            elements = partition(filepath)
            full_text = " ".join([strip_xml_tags(str(el)) for el in elements])
            return full_text
        else:
            if '/' in doi:
                doi_attempt = doi.split('/')[1]
                if doi_attempt in file:
                    print(f'Parsing {filepath}')
                    elements = partition(filepath)
                    full_text = " ".join([strip_xml_tags(str(el)) for el in elements])
                    return full_text

def find_answer_start(context, answer):

    max = 7
    start = context.find(answer[0:max])
    while start == -1 and start >0:
        max -=1
        start = context.find(answer[0:max])
    return start

# %%
# A. For each journal article, list the effects DONE
# B. For each nanomaterial mentioned, list  TODO
squad_sbd4nano = pd.DataFrame()
seen = {}
for index, row in go.iterrows():
    id = str(index)
    title = str(row['doi'])
    if title not in seen.keys(): 
        context = str(get_full_text(title))
        seen[title] = context
        question = f'Which effects on organisms or cells are described upon exposure to graphene oxide?' #A
        text = str(row['quote'])
        if re.match(r'^\s*$', text) is None:
            answer_start = str(find_answer_start(context, text))
            answers = {"text": [text], "answer_start": [answer_start]}
            new_row = pd.DataFrame([id,title,context,question,answers]).transpose()
            squad_sbd4nano = pd.concat([squad_sbd4nano, new_row], ignore_index=True)
    else:
        context = seen[title]
    if row['effect'] != 'NaN' and len(str(row['Material properties'])) > 3:
        effect = row['effect']
        question_b = f'Which are the properties of graphene oxide leading to {effect}?' #B
        props = row['Material properties'].split(".")
        answers = {"text": [], "answer_start": []}
        for prop in props:
            text = prop
            answer_start = str(find_answer_start(context, text))
            if str(answer_start) not in ['0', '-1']:
                answers['text'].append(text)
                answers['answer_start'].append(answer_start)   
        new_row = pd.DataFrame([id,title,context,question,answers]).transpose()
        squad_sbd4nano = pd.concat([squad_sbd4nano, new_row], ignore_index=True)


    answer_start = str(find_answer_start(context, text))
    answers = {"text": text, "answer_start": [answer_start]}
    new_row = pd.DataFrame([id,title,context,question,answers]).transpose()
    squad_sbd4nano = pd.concat([squad_sbd4nano, new_row], ignore_index=True)# B
    # C
    
squad_sbd4nano.columns = ['id', 'title', 'context', 'question', 'answers']
# Out:
# Parsing ../data/docs/tx400385x.pdf
# Parsing ../data/docs/tx400385x.pdf
# Parsing ../data/docs/j.toxlet.2010.11.016.xml
# Parsing ../data/docs/cdd.2010.11.pdf
# Parsing ../data/docs/j.biomaterials.2012.07.040.xml
# Parsing ../data/docs/j.biomaterials.2012.02.021.xml
# Parsing ../data/docs/nl202515a.pdf
# Parsing ../data/docs/s11671-010-9751-6.xml
# Parsing ../data/docs/smll.201201546.pdf
# Parsing ../data/docs/nn101097v.pdf
# Parsing ../data/docs/nn202699t.pdf
# Parsing ../data/docs/A20060216.pdf
# Parsing ../data/docs/ijms221910578.xml
# Parsing ../data/docs/am300253c.pdf
# Parsing ../data/docs/acsomega.2c03171.xml
# Parsing ../data/docs/j.envpol.2017.12.034.xml

# %%
#QC
n = 0
for index, row in squad_sbd4nano.iterrows():
    if len(row['answers']['text']) > 0 and len(row['answers']['text']) == len(row['answers']['answer_start']):
        for i in range(len(row['answers']['text'])):
            n+=1
            print(f'QA #{n} | id: {row["id"]} | text: {row["answers"]["text"][i][0:10]} (...) | start position at: {row["answers"]["answer_start"][i]}')
    else:
        squad_sbd4nano.drop(index)
# Out:
# QA #1 | id: 0 | text: formation  (...) | start position at: 3335
# QA #2 | id: 1 | text: Toxicologi (...) | start position at: -1
# QA #103 | id: 53 | text: The effect (...) | start position at: 51378
# QA #104 | id: 55 | text: GO disrupt (...) | start position at: 19814
# QA #105 | id: 61 | text: The metabo (...) | start position at: 7993
# QA #106 | id: 61 | text: thickness  (...) | start position at: 4390
# QA #107 | id: 61 | text: 1 nm (...) | start position at: 4981
# QA #108 | id: 62 | text: thickness  (...) | start position at: 4390
# QA #109 | id: 62 | text: 1 nm (...) | start position at: 4981
# QA #110 | id: 63 | text: GO film, b (...) | start position at: 17467
# QA #111 | id: 93 | text: nan (...) | start position at: 1622
# QA #112 | id: 97 | text: The result (...) | start position at: 2601
# QA #113 | id: 100 | text: Protein-co (...) | start position at: 233
# QA #114 | id: 101 | text: nan (...) | start position at: -1
# QA #115 | id: 102 | text: GO having  (...) | start position at: 121057
# QA #116 | id: 102 | text:  average t (...) | start position at: 78470
# QA #117 | id: 103 | text:  average t (...) | start position at: 78470
# QA #118 | id: 104 | text: The result (...) | start position at: 870
# QA #119 | id: 104 | text: GO layers  (...) | start position at: 22257
# QA #120 | id: 104 | text:  average t (...) | start position at: 23925
# QA #121 | id: 105 | text: GO layers  (...) | start position at: 22257
# QA #122 | id: 105 | text:  average t (...) | start position at: 23925
# QA #123 | id: 106 | text: GO layers  (...) | start position at: 22257
# QA #124 | id: 106 | text:  average t (...) | start position at: 23925
# QA #125 | id: 107 | text: GO layers  (...) | start position at: 22257
# QA #126 | id: 107 | text:  average t (...) | start position at: 23925
# QA #127 | id: 108 | text: GO layers  (...) | start position at: 22257
# QA #128 | id: 108 | text:  average t (...) | start position at: 23925
# QA #129 | id: 109 | text: GO layers  (...) | start position at: 22257
# QA #130 | id: 109 | text:  average t (...) | start position at: 23925

# %%
squad_sbd4nano.head(5)
# Out:
#   id                      title  \
# 0  0  doi.org/10.1021/tx400385x
# 1  0  doi.org/10.1021/tx400385x
# 2  1                        nan
# 3  1                        nan
# 4  2                        nan
#
#                                              context  \
# 0  Downloaded via MAASTRICHT UNIV on June 26, 202...
# 1  Downloaded via MAASTRICHT UNIV on June 26, 202...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                             question  \
# 0  Which effects on organisms or cells are descri...
# 1  Which effects on organisms or cells are descri...
# 2  Which effects on organisms or cells are descri...
# 3  Which effects on organisms or cells are descri...
# 4  Which effects on organisms or cells are descri...
#
#                                              answers
# 0  {'text': ['formation of hydrogen bonds between...
# 1  {'text': 'formation of hydrogen bonds between ...
# 2  {'text': ['Toxicological aspects related to cy...
# 3  {'text': 'Toxicological aspects related to cyt...
# 4  {'text': 'Toxicological aspects related to cyt...

# %%
squad_sbd4nano.describe()
# Out:
#          id                         title  \
# count   170                           170
# unique  110                            18
# top     102  dx.doi.org/10.1021/tx400385x
# freq      3                            60
#
#                                                   context  \
# count                                                 170
# unique                                                 16
# top     Downloaded via MAASTRICHT UNIV on June 26, 202...
# freq                                                   62
#
#                                                  question  \
# count                                                 170
# unique                                                  1
# top     Which effects on organisms or cells are descri...
# freq                                                  170
#
#                                                   answers
# count                                                 170
# unique                                                 59
# top     {'text': 'GO film, beyond not exerting any cyt...
# freq                                                   28

# %%
squad_sbd4nano.to_csv('../data/squad_sbd4nano.tsv', sep='\t')
